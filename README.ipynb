# %% [markdown]
# The files are big, thus some of the folders referenced in the Default_Data_File_HCSS_Exam.ipynb are not present.
#
# These files are: "Intermediary_files" , "ParlaMint_files" , and "ParlaMint_processed" .
#
# "Intermediary_files" and "ParlaMint_processed" do not have anything in them prior to running the code, so as long as you have empty folders with those names right under the "HCSS_Exam_2026" folder, that should be fine.
#
# "ParlaMint_files" consists of the ParlaMint-NL-en.ana.tgz file retrieved from the download page.
#
# The python environment is listed in environment.yml
